# %%
import pandas as pd
import sqlite3

# %%
ss = pd.read_csv('state_stats.csv')
ud = pd.read_csv('ufo_data.csv', low_memory = False)

# %%
ss
# Out:
#                     name  drug_deaths abbreviation  sightings  \
# 0                Alabama          724           al        691
# 1                 Alaska          107           ak        354
# 2                Arizona         1725           az       2689
# 3               Arkansas          439           ar        666
# 4             California         5515           ca       9655
# 5               Colorado          992           co       1505
# 6            Connecticut         1087           ct        968
# 7               Delaware          403           de        183
# 8   District of Columbia          300           dc         99
# 9                Florida         4921           fl       4200
# 10               Georgia         1384           ga       1347
# 11                Hawaii          223           hi        353
# 12                 Idaho          249           id        554
# 13              Illinois         2687           il       2645
# 14               Indiana         1591           in       1386
# 15                  Iowa          278           ia        707
# 16                Kansas          348           ks        653
# 17              Kentucky         1339           ky        914
# 18             Louisiana         1162           la        598
# 19                 Maine          324           me        633
# 20              Maryland         2392           md        911
# 21         Massachusetts         2212           ma       1358
# 22              Michigan         2513           mi       2071
# 23             Minnesota          665           mn       1081
# 24           Mississippi          288           ms        415
# 25              Missouri         1664           mo       1576
# 26               Montana          120           mt        510
# 27              Nebraska          147           ne        405
# 28                Nevada          752           nv        905
# 29         New Hampshire          446           nh        535
# 30            New Jersey         2819           nj       1512
# 31            New Mexico          513           nm        815
# 32              New York         2144           ny       3219
# 33        North Carolina         2225           nc       1869
# 34          North Dakota           63           nd        138
# 35                  Ohio         4036           oh       2425
# 36              Oklahoma          675           ok        766
# 37                Oregon          547           or       1845
# 38          Pennsylvania         4403           pa       2582
# 39          Rhode Island          344           ri        290
# 40        South Carolina         1116           sc       1076
# 41          South Dakota           56           sd        196
# 42             Tennessee         1881           tn       1193
# 43                 Texas         2968           tx       3677
# 44                  Utah          634           ut        743
# 45               Vermont          147           vt        307
# 46              Virginia         1464           va       1393
# 47            Washington         1181           wa       4268
# 48         West Virginia          887           wv        486
# 49             Wisconsin         1081           wi       1333
# 50               Wyoming           60           wy        205
#
#     avg_sighting_duration  code  census_area
# 0             1393.408828     1    50645.326
# 1             4231.830508     2   570640.950
# 2             5949.009338     4   113594.084
# 3           100867.138900     5    52035.477
# 4             3928.781072     6   155779.220
# 5             3024.394751     8   103641.888
# 6            13089.214930     9     4842.355
# 7              868.904372    10     1948.543
# 8             1161.224545    11       61.048
# 9            13504.459260    12    53624.759
# 10            7968.701633    13    57513.485
# 11           19267.543910    15     6422.628
# 12             968.556498    16    82643.117
# 13             877.362219    17    55518.930
# 14            3094.797763    18    35826.109
# 15             949.626591    19    55857.130
# 16            1514.714395    20    81758.717
# 17            4205.386761    21    39486.338
# 18           11481.575250    22    43203.905
# 19            3066.431122    23    30842.923
# 20             833.780790    24     9707.241
# 21            1312.187776    25     7800.058
# 22            3885.088653    26    56538.901
# 23            1411.120564    27    79626.743
# 24            8784.190361    28    46923.274
# 25            1144.388198    29    68741.522
# 26            2148.723529    30   145545.801
# 27            1063.565432    31    76824.171
# 28            2926.016519    32   109781.180
# 29            2141.602804    33     8952.651
# 30            5299.992341    34     7354.220
# 31            5185.816675    35   121298.148
# 32            2914.711572    36    47126.399
# 33            1281.831648    37    48617.905
# 34            1105.405797    38    69000.798
# 35            1576.187773    39    40860.694
# 36           14929.384200    40    68594.921
# 37            1064.210450    41    95988.013
# 38            3990.113091    42    44742.703
# 39            1811.881034    44     1033.814
# 40            1102.498885    45    30060.696
# 41            2608.640306    46    75811.000
# 42            1610.461526    47    41234.896
# 43            2371.343283    48   261231.711
# 44            4739.033647    49    82169.620
# 45            1077.587948    50     9216.657
# 46            9862.555276    51    39490.086
# 47           13545.595630    53    66455.521
# 48            6239.355967    54    24038.210
# 49            2047.964966    55    54157.805
# 50            1841.629273    56    97093.141

# %%
ud
# Out:
#                datetime                  city state country     shape  \
# 0      10/10/1949 20:30            san marcos    tx      us  cylinder
# 1      10/10/1949 21:00          lackland afb    tx     NaN     light
# 2      10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3      10/10/1956 21:00                  edna    tx      us    circle
# 4      10/10/1960 20:00               kaneohe    hi      us     light
# ...                 ...                   ...   ...     ...       ...
# 80327    9/9/2013 21:15             nashville    tn      us     light
# 80328    9/9/2013 22:00                 boise    id      us    circle
# 80329    9/9/2013 22:00                  napa    ca      us     other
# 80330    9/9/2013 22:20                vienna    va      us    circle
# 80331    9/9/2013 23:00                edmond    ok      us     cigar
#
#       duration duration_hours  \
# 0         2700     45 minutes
# 1         7200        1-2 hrs
# 2           20     20 seconds
# 3           20       1/2 hour
# 4          900     15 minutes
# ...        ...            ...
# 80327      600     10 minutes
# 80328     1200     20 minutes
# 80329     1200           hour
# 80330        5      5 seconds
# 80331     1020     17 minutes
#
#                                                 comments date_posted latitude  \
# 0      This event took place in early fall around 194...   4/27/2004  29.8831
# 1      1949 Lackland AFB&#44 TX.  Lights racing acros...  12/16/2005  29.3842
# 2      Green/Orange circular disc over Chester&#44 En...   1/21/2008     53.2
# 3      My older brother and twin sister were leaving ...   1/17/2004  28.9783
# 4      AS a Marine 1st Lt. flying an FJ4B fighter/att...   1/22/2004  21.4181
# ...                                                  ...         ...      ...
# 80327  Round from the distance/slowly changing colors...   9/30/2013  36.1658
# 80328  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...   9/30/2013  43.6136
# 80329                                       Napa UFO&#44   9/30/2013  38.2972
# 80330  Saw a five gold lit cicular craft moving fastl...   9/30/2013  38.9011
# 80331  2 witnesses 2  miles apart&#44 Red &amp; White...   9/30/2013  35.6528
#
#        longitude    year  month
# 0       -97.9411  1949.0   10.0
# 1       -98.5811  1949.0   10.0
# 2        -2.9167  1955.0   10.0
# 3       -96.6458  1956.0   10.0
# 4      -157.8036  1960.0   10.0
# ...          ...     ...    ...
# 80327   -86.7844  2013.0    9.0
# 80328  -116.2025  2013.0    9.0
# 80329  -122.2844  2013.0    9.0
# 80330   -77.2656  2013.0    9.0
# 80331   -97.4778  2013.0    9.0
#
# [80332 rows x 13 columns]

# %%
ud.dropna(inplace=True)
ud
# Out:
#                datetime        city state country     shape duration  \
# 0      10/10/1949 20:30  san marcos    tx      us  cylinder     2700
# 3      10/10/1956 21:00        edna    tx      us    circle       20
# 4      10/10/1960 20:00     kaneohe    hi      us     light      900
# 5      10/10/1961 19:00     bristol    tn      us    sphere      300
# 7      10/10/1965 23:45     norwalk    ct      us      disk     1200
# ...                 ...         ...   ...     ...       ...      ...
# 80327    9/9/2013 21:15   nashville    tn      us     light      600
# 80328    9/9/2013 22:00       boise    id      us    circle     1200
# 80329    9/9/2013 22:00        napa    ca      us     other     1200
# 80330    9/9/2013 22:20      vienna    va      us    circle        5
# 80331    9/9/2013 23:00      edmond    ok      us     cigar     1020
#
#       duration_hours                                           comments  \
# 0         45 minutes  This event took place in early fall around 194...
# 3           1/2 hour  My older brother and twin sister were leaving ...
# 4         15 minutes  AS a Marine 1st Lt. flying an FJ4B fighter/att...
# 5          5 minutes  My father is now 89 my brother 52 the girl wit...
# 7         20 minutes  A bright orange color changing to reddish colo...
# ...              ...                                                ...
# 80327     10 minutes  Round from the distance/slowly changing colors...
# 80328     20 minutes  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...
# 80329           hour                                       Napa UFO&#44
# 80330      5 seconds  Saw a five gold lit cicular craft moving fastl...
# 80331     17 minutes  2 witnesses 2  miles apart&#44 Red &amp; White...
#
#       date_posted latitude  longitude    year  month
# 0       4/27/2004  29.8831   -97.9411  1949.0   10.0
# 3       1/17/2004  28.9783   -96.6458  1956.0   10.0
# 4       1/22/2004  21.4181  -157.8036  1960.0   10.0
# 5       4/27/2007   36.595   -82.1889  1961.0   10.0
# 7       10/2/1999  41.1175   -73.4083  1965.0   10.0
# ...           ...      ...        ...     ...    ...
# 80327   9/30/2013  36.1658   -86.7844  2013.0    9.0
# 80328   9/30/2013  43.6136  -116.2025  2013.0    9.0
# 80329   9/30/2013  38.2972  -122.2844  2013.0    9.0
# 80330   9/30/2013  38.9011   -77.2656  2013.0    9.0
# 80331   9/30/2013  35.6528   -97.4778  2013.0    9.0
#
# [66040 rows x 13 columns]

# %%
db_conn = sqlite3.connect('../database.sqlite')

# %%
c = db_conn.cursor()

# %%
c.execute('DROP TABLE IF EXISTS ufo_data;')

c.execute(
    
"""
CREATE TABLE ufo_data(
id SERIAL PRIMARY KEY,
datetime VARCHAR,
city VARCHAR,
state VARCHAR,
country VARCHAR,
shape VARCHAR,
duration FLOAT,
duration_hours VARCHAR,
comments VARCHAR,
date_posted VARCHAR,
latitude FLOAT,
longitude FLOAT,
year FLOAT,
month FLOAT,
Foreign Key (state) REFERENCES state_stats(abbreviation));

"""
    
)

# %%
c.execute('DROP TABLE IF EXISTS state_stats;')

c.execute(
    
"""

CREATE TABLE state_stats(
name VARCHAR,
drug_deaths INT,
abbreviation VARCHAR,
sightings INT,
avg_sighting_duration FLOAT,
code VARCHAR,
census_area FLOAT,
PRIMARY KEY (abbreviation));

"""
    
)

# %%
ud.to_sql('ufo_data', db_conn, if_exists='append', index=False)
ss.to_sql('state_stats', db_conn, if_exists='append', index=False)

# %%
# Test 1 with Pandas

pd.read_sql("SELECT * FROM ufo_data LIMIT 3", db_conn)
# Out:
#      id          datetime        city state country     shape  duration  \
# 0  None  10/10/1949 20:30  san marcos    tx      us  cylinder    2700.0
# 1  None  10/10/1956 21:00        edna    tx      us    circle      20.0
# 2  None  10/10/1960 20:00     kaneohe    hi      us     light     900.0
#
#   duration_hours                                           comments  \
# 0     45 minutes  This event took place in early fall around 194...
# 1       1/2 hour  My older brother and twin sister were leaving ...
# 2     15 minutes  AS a Marine 1st Lt. flying an FJ4B fighter/att...
#
#   date_posted  latitude  longitude    year  month
# 0   4/27/2004   29.8831   -97.9411  1949.0   10.0
# 1   1/17/2004   28.9783   -96.6458  1956.0   10.0
# 2   1/22/2004   21.4181  -157.8036  1960.0   10.0

# %%
# Test 2 with Pandas

pd.read_sql("SELECT * FROM state_stats LIMIT 3", db_conn)
# Out:
#       name  drug_deaths abbreviation  sightings  avg_sighting_duration code  \
# 0  Alabama          724           al        691            1393.408828    1
# 1   Alaska          107           ak        354            4231.830508    2
# 2  Arizona         1725           az       2689            5949.009338    4
#
#    census_area
# 0    50645.326
# 1   570640.950
# 2   113594.084

# %%
# Test with SQLAlchemy

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
from scipy.stats import ttest_ind

# %%
engine = create_engine("sqlite:///../database.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['state_stats', 'ufo_data']

# %%
ufo_data = Base.classes.ufo_data
state_stats = Base.classes.state_stats

# %%
session = Session(engine)

# %%
sightings = session.query(state_stats.sightings)

# %%
for s in sightings[:10]:
    print(s)
# Out:
# (691,)
# (354,)
# (2689,)
# (666,)
# (9655,)
# (1505,)
# (968,)
# (183,)
# (99,)
# (4200,)
